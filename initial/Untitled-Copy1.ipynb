# %%
import numpy as np
from pyc_linear import fn_linear
from fn_flatten import fn_flatten
from fn_relu import fn_relu
from fn_pool import fn_pool
from pyc_conv import fn_conv
from pyc_softmax import fn_softmax
from pyc_loss import loss_crossentropy

# %%
from pyc_cal_grad import calc_gradient
from pyc_inference import inference
from init_layers import init_layers
from train import train
from pyc_update_weight import update_weights 
# ate_weights_SGD_momenum

# %%
import sys
sys.path += ['layers']
# from loss_euclidean import loss_euclidean

from load_MNIST_images import load_MNIST_images
from load_MNIST_labels import load_MNIST_labels

# Load training data
train_data = load_MNIST_images('train-images.idx3-ubyte')
print (train_data.shape)
train_label = load_MNIST_labels('train-labels.idx1-ubyte')
# Load testing data
test_data = load_MNIST_images('t10k-images.idx3-ubyte')
test_label = load_MNIST_labels('t10k-labels.idx1-ubyte')
# Out:
# (28, 28, 1, 60000)

# %%
from init_model import init_model

# %%
trainshape = train_data.shape
num_in = trainshape[0]*trainshape[1]*trainshape[2]*trainshape[3]

l = [init_layers('conv', {'filter_size': 2,
                          'filter_depth': 1,
                          'num_filters': 6}),
     init_layers('pool', {'filter_size': 2,
                          'stride': 2}),
     init_layers('conv', {'filter_size': 4,
                          'filter_depth': 6,
                          'num_filters': 16}),
     init_layers('pool', {'filter_size': 2,
                          'stride': 2}),
     init_layers('relu', {}),
     init_layers('flatten', {}),
     init_layers('linear', {'num_in': 400,
                    'num_out': 120}),
    init_layers('linear', {'num_in': 120,
                    'num_out': 84}),
     init_layers('linear', {'num_in': 84,
                            'num_out': 10}),
     init_layers('softmax', {})]

params = {
#     "learning_rate": .01,
#     "weight_decay": .0005,
    "learning_rate": .01,
    "weight_decay": .0005,
    "batch_size": 128,
    "save_file": 'model.npz'
}

model = init_model(l, list(train_data[:,:,:,0].shape), 10, True)
# Out:
# Input size:
# [28, 28, 1]
# Layer 0 output size:
# (27, 27, 6)
# Layer 1 output size:
# (13, 13, 6)
# Layer 2 output size:
# (10, 10, 16)
# Layer 3 output size:
# (5, 5, 16)
# Layer 4 output size:
# (5, 5, 16)
# Layer 5 output size:
# (400,)
# Layer 6 output size:
# (120,)
# Layer 7 output size:
# (84,)
# Layer 8 output size:
# (10,)
# Final output size:
# (10,)
# Provided output size (should match above):
# 10
# (Batch dimension not included)

# %%
input = train_data
numIters = 3500
label = train_label 
max_model=None
max_acc=0


lr = params.get("learning_rate", .01)
# Weight decay
wd = params.get("weight_decay", .0005)
# Batch size
batch_size = params.get("batch_size", 128)
# There is a good chance you will want to save your network model during/after
# training. It is up to you where you save and how often you choose to back up
# your model. By default the code saves the model in 'model.npz'.
save_file = params.get("save_file", 'model.npz')

# update_params will be passed to your update_weights function.
# This allows flexibility in case you want to implement extra features like momentum.
update_params = {"learning_rate": lr,
                 "weight_decay": wd }

print("Learning Rate: ", lr)

num_inputs = input.shape[-1]
loss = np.zeros((numIters,))

for i in range(numIters):
    # TODO: One training iteration
    # Steps:
    #   (1) Select a subset of the input to use as a batch
    #   (2) Run inference on the batch
    #   (3) Calculate loss and determine accuracy
    #   (4) Calculate gradients
    #   (5) Update the weights of the model
    # Optionally,
    #   (1) Monitor the progress of training
    #   (2) Save your learnt model, using ``np.savez(save_file, **model)``
    batch_num = np.random.randint(num_inputs, size=batch_size)
    sample_input = input[:,:,:,batch_num]

    sample_label = label[batch_num]
    sample_output, sample_activations = inference(model, sample_input)
    loss[i], dv_gradient = loss_crossentropy(sample_output, sample_label, {}, True)

    if (i % 5 == 0):
        print("Epoch: ", i, "loss: ", loss[i])
        count = 0.0
        for j in range (batch_size):
            if (np.argmax(sample_output[:,j]) == sample_label[j]):
                count +=1.0
        print("The accuracy is: ", count/batch_size)
        if count/batch_size>max_acc:
            max_acc=count/batch_size
            max_model=model.copy()

    sample_grads = calc_gradient(model, sample_input, sample_activations, dv_gradient)
    model = update_weights (model, sample_grads, update_params)
# Out:
# Learning Rate:  0.01
# pyc inference
# pyc loss
# Epoch:  0 loss:  2.5369009640402007
# The accuracy is:  0.09375
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  5 loss:  2.391353479444814
# The accuracy is:  0.1015625
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  10 loss:  2.340708316717555
# The accuracy is:  0.0546875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  15 loss:  2.2865001321663225
# The accuracy is:  0.1328125
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  20 loss:  2.2860731907961602
# The accuracy is:  0.15625
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  25 loss:  2.3039379263593527
# The accuracy is:  0.15625
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  30 loss:  2.265310958161161
# The accuracy is:  0.2109375
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  35 loss:  2.275724115377459
# The accuracy is:  0.1875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  40 loss:  2.2660731086890435
# The accuracy is:  0.2578125
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  45 loss:  2.2640455049025707
# The accuracy is:  0.28125
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  50 loss:  2.2684941136438006
# The accuracy is:  0.2265625
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  55 loss:  2.2706351665558646
# The accuracy is:  0.265625
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  60 loss:  2.2621758949941153
# The accuracy is:  0.2421875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  65 loss:  2.2522980803937274
# The accuracy is:  0.203125
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  70 loss:  2.2393434593709474
# The accuracy is:  0.2578125
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  75 loss:  2.2542845545197965
# The accuracy is:  0.1875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  80 loss:  2.24429461510054
# The accuracy is:  0.265625
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  85 loss:  2.2318465248758863
# The accuracy is:  0.3046875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  90 loss:  2.2281110234773434
# The accuracy is:  0.2421875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  95 loss:  2.211950467595617
# The accuracy is:  0.34375
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  100 loss:  2.1939821845698697
# The accuracy is:  0.3125
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  105 loss:  2.2302841245379077
# The accuracy is:  0.25
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  110 loss:  2.2011961713389736
# The accuracy is:  0.3125
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  115 loss:  2.164596362332139
# The accuracy is:  0.4140625
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  120 loss:  2.1562380155909215
# The accuracy is:  0.4375
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  125 loss:  2.16973721047772
# The accuracy is:  0.4296875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  130 loss:  2.147218153003497
# The accuracy is:  0.421875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  135 loss:  2.1860689914618137
# The accuracy is:  0.296875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  140 loss:  2.154957684608579
# The accuracy is:  0.3828125
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  145 loss:  2.1488949901774177
# The accuracy is:  0.3359375
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  150 loss:  2.11645577995305
# The accuracy is:  0.4375
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  155 loss:  2.102505055858482
# The accuracy is:  0.5234375
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  160 loss:  2.0728269965029567
# The accuracy is:  0.4921875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  165 loss:  2.050099354764291
# The accuracy is:  0.5546875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  170 loss:  2.1434914374965186
# The accuracy is:  0.34375
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  175 loss:  2.0667391826227655
# The accuracy is:  0.4453125
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:

# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  3485 loss:  0.2617331580987905
# The accuracy is:  0.953125
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  3490 loss:  0.29488718790758606
# The accuracy is:  0.921875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  3495 loss:  0.3966091601485434
# The accuracy is:  0.90625
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight

# %%
np.savez("model_3.npz", **max_model)

# %%
model_test = np.load('model_3.npz', allow_pickle=True)

test_output, activations = inference(model, test_data)
count = 0.0
for j in range (test_data.shape[-1]):
    if (np.argmax(test_output[:,j]) == test_label[j]):
        count +=1.0
print("The accuracy is: ", count/test_data.shape[-1])
# Out:
# pyc inference
# The accuracy is:  0.9351

# %%
min(loss)
# Out:
# 0.16578093055766147

# %%
model_extra=model.copy()
extra_iter=1000
extra_loss= np.zeros((extra_iter,))
max_acc_e=0
max_model_e=None
for j in range(extra_iter):
    # TODO: One training iteration
    # Steps:
    #   (1) Select a subset of the input to use as a batch
    #   (2) Run inference on the batch
    #   (3) Calculate loss and determine accuracy
    #   (4) Calculate gradients
    #   (5) Update the weights of the model
    # Optionally,
    #   (1) Monitor the progress of training
    #   (2) Save your learnt model, using ``np.savez(save_file, **model)``
    batch_num = np.random.randint(num_inputs, size=batch_size)
    sample_input = input[:,:,:,batch_num]

    sample_label = label[batch_num]
    sample_output, sample_activations = inference(model_extra, sample_input)
    extra_loss[j], dv_gradient = loss_crossentropy(sample_output, sample_label, {}, True)

    if (j % 5 == 0):
        print("Epoch: ", j, "loss: ", extra_loss[j])
        count = 0.0
        for j in range (batch_size):
            if (np.argmax(sample_output[:,j]) == sample_label[j]):
                count +=1.0
        print("The accuracy is: ", count/batch_size)
        if count/batch_size>max_acc:
            max_acc_e=count/batch_size
            max_model_e=model_extra.copy()

    sample_grads = calc_gradient(model_extra, sample_input, sample_activations, dv_gradient)
    model_extra = update_weights (model_extra, sample_grads, update_params)
# Out:
# pyc inference
# pyc loss
# Epoch:  0 loss:  0.3630820949627249
# The accuracy is:  0.921875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  5 loss:  0.30655829063793394
# The accuracy is:  0.9453125
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  10 loss:  0.34339648491384656
# The accuracy is:  0.9140625
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  15 loss:  0.31658316004358744
# The accuracy is:  0.9140625
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  20 loss:  0.36414449613455324
# The accuracy is:  0.8984375
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  25 loss:  0.24487049062004554
# The accuracy is:  0.9609375
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  30 loss:  0.27387526349640057
# The accuracy is:  0.921875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  35 loss:  0.4085883090884475
# The accuracy is:  0.875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  40 loss:  0.24440655023313607
# The accuracy is:  0.9140625
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  45 loss:  0.26264506117680664
# The accuracy is:  0.9453125
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  50 loss:  0.32176237804716307
# The accuracy is:  0.9375
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  55 loss:  0.2414510880522672
# The accuracy is:  0.984375
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  60 loss:  0.28867715642310005
# The accuracy is:  0.9375
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  65 loss:  0.2640282204872498
# The accuracy is:  0.953125
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  70 loss:  0.26241673915906305
# The accuracy is:  0.9296875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  75 loss:  0.32424624290571985
# The accuracy is:  0.9296875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  80 loss:  0.29235590669546485
# The accuracy is:  0.9296875
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  85 loss:  0.2652196769226569
# The accuracy is:  0.9453125
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# Epoch:  90 loss:  0.29405862799017846
# The accuracy is:  0.9375
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
# pyc loss
# pyc cal grad
# pyc update weight
# pyc inference
